# %%
import scipy.io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
#imports for LSTM
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.models import load_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_tweedie_deviance
from sklearn.metrics import mean_poisson_deviance
from sklearn.metrics import mean_gamma_deviance
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import tensorflow as tf
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import RepeatVector, TimeDistributed

# %%
sub1_train = scipy.io.loadmat('sub1_comp.mat')
sub1_test = scipy.io.loadmat('sub1_testlabels.mat')
sub2_train = scipy.io.loadmat('sub2_comp.mat')
sub2_test = scipy.io.loadmat('sub2_testlabels.mat')
sub3_train = scipy.io.loadmat('sub3_comp.mat')
sub3_test = scipy.io.loadmat('sub3_testlabels.mat')

# %%
sub1_x_train=pd.DataFrame(sub1_train['train_data'])
sub1_y_train=pd.DataFrame(sub1_train['train_dg'])
sub1_x_test=pd.DataFrame(sub1_train['test_data'])
sub1_y_test=pd.DataFrame(sub1_test['test_dg'])

sub2_x_train=pd.DataFrame(sub2_train['train_data'])
sub2_y_train=pd.DataFrame(sub2_train['train_dg'])
sub2_x_test=pd.DataFrame(sub2_train['test_data'])
sub2_y_test=pd.DataFrame(sub2_test['test_dg'])

sub3_x_train=pd.DataFrame(sub3_train['train_data'])
sub3_y_train=pd.DataFrame(sub3_train['train_dg'])
sub3_x_test=pd.DataFrame(sub3_train['test_data'])
sub3_y_test=pd.DataFrame(sub3_test['test_dg'])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(sub1_x_train, sub1_y_train)
y_pred = regressor.predict(sub1_x_test)
y_pred_df=pd.DataFrame(y_pred)
y_pred_df
# Out:
#                0         1         2         3         4
# 0       0.061711 -0.134069 -0.083193 -0.140037 -0.202012
# 1       0.042936 -0.148053 -0.106645 -0.144776 -0.194772
# 2       0.023721 -0.163879 -0.125486 -0.155095 -0.179372
# 3       0.017380 -0.175030 -0.132533 -0.162799 -0.158078
# 4       0.022150 -0.181710 -0.136557 -0.164108 -0.140603
# ...          ...       ...       ...       ...       ...
# 199995 -0.150207 -0.189723 -0.323839 -0.320197 -0.022620
# 199996 -0.127824 -0.201255 -0.333744 -0.311018 -0.025591
# 199997 -0.106062 -0.203802 -0.335946 -0.301247 -0.029026
# 199998 -0.084286 -0.194192 -0.323854 -0.289329 -0.027196
# 199999 -0.063057 -0.176188 -0.302522 -0.278211 -0.023212
#
# [200000 rows x 5 columns]

# %%
#find correlation between y_pred and y_test
from scipy.stats import pearsonr

array1=np.array(sub1_y_test)
array2=np.array(y_pred_df)

corr, _ = pearsonr(array1.flatten(), array2.flatten())
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.032

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(sub2_x_train, sub2_y_train)
y_pred = regressor.predict(sub2_x_test)
y_pred_df=pd.DataFrame(y_pred)
y_pred_df
# Out:
#                0         1         2         3         4
# 0      -0.098722 -0.148431  0.139906 -0.243738 -0.198761
# 1      -0.100529 -0.133554  0.137799 -0.233801 -0.189573
# 2      -0.093558 -0.118250  0.139344 -0.225527 -0.186121
# 3      -0.081199 -0.110067  0.140852 -0.224203 -0.189772
# 4      -0.062361 -0.110019  0.150139 -0.219641 -0.194188
# ...          ...       ...       ...       ...       ...
# 199995 -0.052147 -0.207971  0.260655 -0.297928 -0.272362
# 199996 -0.037228 -0.197841  0.272530 -0.295488 -0.271412
# 199997 -0.038117 -0.206459  0.268742 -0.297925 -0.279625
# 199998 -0.052863 -0.225068  0.247013 -0.304617 -0.292765
# 199999 -0.069985 -0.244778  0.221104 -0.309146 -0.304514
#
# [200000 rows x 5 columns]

# %%
#find correlation between y_pred and y_test
from scipy.stats import pearsonr

array1=np.array(sub1_y_test)
array2=np.array(y_pred_df)

corr, _ = pearsonr(array1.flatten(), array2.flatten())
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.026

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(sub3_x_train, sub3_y_train)
y_pred = regressor.predict(sub3_x_test)
y_pred_df=pd.DataFrame(y_pred)
y_pred_df
# Out:
#                0         1         2         3         4
# 0       0.240074  0.310829 -0.046606  0.240774  0.336534
# 1       0.214322  0.280445 -0.062490  0.223500  0.322917
# 2       0.170806  0.200521 -0.092294  0.161136  0.263326
# 3       0.144574  0.201802 -0.089639  0.144871  0.251589
# 4       0.123496  0.260713 -0.067511  0.167252  0.283556
# ...          ...       ...       ...       ...       ...
# 199995  0.026218  0.178791 -0.164325 -0.068453  0.013634
# 199996  0.092666  0.235599 -0.149798 -0.025516  0.046419
# 199997  0.176024  0.336717 -0.106066  0.065990  0.105691
# 199998  0.208585  0.347869 -0.095841  0.095794  0.104627
# 199999  0.181391  0.273965 -0.129660  0.056286  0.057687
#
# [200000 rows x 5 columns]

# %%
#find correlation between y_pred and y_test
from scipy.stats import pearsonr

array1=np.array(sub3_y_test)
array2=np.array(y_pred_df)

corr, _ = pearsonr(array1.flatten(), array2.flatten())
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.004
